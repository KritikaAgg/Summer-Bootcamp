# %%
import os
import numpy as np
import pretty_midi
from mido import MidiFile, MidiTrack, Message
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, LeakyReLU, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
def read_midi(file_path):
    try:
        midi = pretty_midi.PrettyMIDI(file_path)
        notes = []
        for instrument in midi.instruments:
            for note in instrument.notes:
                notes.append((note.pitch, note.start))
        return notes
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return []

# %%
def load_midi_files(folder_path):
    all_notes = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.mid'):
                file_path = os.path.join(root, file)
                notes = read_midi(file_path)
                if notes:  # Only add if notes were successfully read
                    all_notes.append(notes)
    return all_notes

# %%
midi_folder_path = "C:/Users/Student_B21/Downloads/Model"
all_midi_notes = load_midi_files(midi_folder_path)
# Out:
# C:\Users\Student_B21\Documents\Custom Office Templates\Python\Lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Error reading C:/Users/Student_B21/Downloads/Model\10cc\Dreadlock_Holiday.4.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\3T\Why.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\4_Non_Blondes\Whats_Up.5.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\a-ha\Take_On_Me.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Aaron_Neville\Tell_It_Like_It_Is.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\ABBA\Ive_Been_Waiting_For_You.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\ABBA\One_Of_Us.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\ABBA\Take_a_Chance_on_Me.3.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\ABBA\Thank_You_for_the_Music.2.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\ABBA\Voulez_Vous.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Aerosmith\Dream_On.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Aerosmith\Pink.3.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\Alice_in_Chains\Sludge_Factory.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\Alison_Moyet\All_Cried_Out.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Amedeo_Minghi\Decenni.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Amos,_Tori\The_Wrong_Band.mid: Could not decode key with 5 flats and mode 255
# Error reading C:/Users/Student_B21/Downloads/Model\Andre_Brasseur\Early_Bird_Satellite.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Andre_Hazes\Ik_meen_t.2.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Aqua\Dr_Jones.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Asia\Dont_Cry.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Barry_Manilow\Copa_Cabana_disco_.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Basie\I_Left_My_Heart_in_San_Francisco.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Beastie_Boys\Girls.mid: Could not decode key with 1 flats and mode 255
# Error reading C:/Users/Student_B21/Downloads/Model\Bee_Gees\How_Can_You_Mend_a_Broken_Heart.1.mid: MIDI file has a largest tick of 12884927490, it is likely corrupt
# Error reading C:/Users/Student_B21/Downloads/Model\Bee_Gees\Stayin_Alive.3.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading C:/Users/Student_B21/Downloads/Model\Bee_Gees\Too_Much_Heaven.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Bernstein_Leonard\West_Side_Story_Medley.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Billy_Joel\Movin_Out_Anthonys_Song_.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Billy_Joel\Pressure.2.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Billy_Joel\Pressure.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Billy_Swan\I_Can_Help.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Blondie\Dreaming.mid: MIDI file has a largest tick of 4312862115, it is likely corrupt
# Error reading C:/Users/Student_B21/Downloads/Model\Bon_Jovi\Blaze_of_Glory.2.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\Boyz_II_Men\End_of_the_Road.2.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Brian_McKnight\On_the_Down_Low.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\Bruce_Springsteen\Tenth_Avenue_Freeze-Out.1.mid: MIDI file has a largest tick of 33639950, it is likely corrupt
# Error reading C:/Users/Student_B21/Downloads/Model\Bryan_Adams\Everything_I_Do_I_Do_It_For_You.7.mid: MThd not found. Probably not a MIDI file
# Error reading C:/Users/Student_B21/Downloads/Model\Bryson\Tonight_I_Celebrate_My_Love_For_You.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Buddy_Holly\Peggy_Sue.1.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\Bush\Glycerine.1.mid: Could not decode key with 1 flats and mode 255
# Error reading C:/Users/Student_B21/Downloads/Model\Busta_Rhymes\Woo_Hah.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Cabrel_Francis\Encore_et_encore.mid: Could not decode key with 4 flats and mode 255
# Error reading C:/Users/Student_B21/Downloads/Model\
1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Offspring\Gone_Away.1.mid: MIDI file has a largest tick of 196929468, it is likely corrupt
# Error reading C:/Users/Student_B21/Downloads/Model\The_Offspring\No_Hero.mid: MThd not found. Probably not a MIDI file
# Error reading C:/Users/Student_B21/Downloads/Model\The_Outhere_Brothers\Dont_Stop_Wiggle_Wiggle_.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Platters\Only_You.5.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Police\Every_Little_Thing_She_Does_Is_Magic.4.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Police\So_Lonely.1.mid: Message length 2093056 exceeds maximum length 1000000
# Error reading C:/Users/Student_B21/Downloads/Model\The_Prodigy\Climbatize.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Prodigy\Wind_It_Up.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Rolling_Stones\The_Last_Time.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\The_Smashing_Pumpkins\Cherub_Rock.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\The_Stylistics\Im_Stone_in_Love_With_You.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Third_Eye_Blind\Semi-Charmed_Life.1.mid: MThd not found. Probably not a MIDI file
# Error reading C:/Users/Student_B21/Downloads/Model\Third_Eye_Blind\Semi-Charmed_Life.mid: MThd not found. Probably not a MIDI file
# Error reading C:/Users/Student_B21/Downloads/Model\Tom_Jones\Delilah.5.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Tool\Flood.mid: MThd not found. Probably not a MIDI file
# Error reading C:/Users/Student_B21/Downloads/Model\Toto\I_Wont_Hold_You_Back.mid: Could not decode key with 3 flats and mode 255
# Error reading C:/Users/Student_B21/Downloads/Model\TURNER_TINA\Notbush_City_Limits.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\U2\Walk_On.mid: MThd not found. Probably not a MIDI file
# Error reading C:/Users/Student_B21/Downloads/Model\U2\Where_the_Streets_Have_No_Name.7.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\UB40\Homely_Girl.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Us3\Cantaloop.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Vangelis\Chariots_of_Fire.5.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Van_Halen\Jump.5.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Van_Halen\Me_Wise_Magic.mid:
# Error reading C:/Users/Student_B21/Downloads/Model\Van_Halen\Right_Now.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Whigfield\Saturday_Night.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Whitney_Houston\Im_Every_Woman.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Whitney_Houston\Saving_All_My_Love_For_You.2.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Wonder_Stevie\Happy_Birthday.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Wonder_Stevie\Sir_Duke.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Yanni\Aria.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Yanni\Marching_Season.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Yanni\Secret_Vows.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Yanni\Swept_Away.mid: running status without last_status
# Error reading C:/Users/Student_B21/Downloads/Model\Yanni\The_Rain_Must_Fall.1.mid: data byte must be in range 0..127
# Error reading C:/Users/Student_B21/Downloads/Model\Yazz_and_plastic_population\The_Only_Way_Is_Up.1.mid: data byte must be in range 0..127

# %%
def normalize_notes(all_notes):
    all_notes_flat = [note for sublist in all_notes for note in sublist]
    min_note = min(all_notes_flat, key=lambda x: x[0])[0]
    max_note = max(all_notes_flat, key=lambda x: x[0])[0]
    normalized_notes = [(note[0] - min_note) / (max_note - min_note) for note in all_notes_flat]
    return np.array(normalized_notes).reshape(-1, 1), min_note, max_note  # Return three values

normalized_notes, min_note, max_note = normalize_notes(all_midi_notes)

# %%
def build_generator(latent_dim):
    model = tf.keras.Sequential()
    model.add(layers.Dense(128, activation='relu', input_dim=latent_dim))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
def build_discriminator():
    model = tf.keras.Sequential()
    model.add(layers.Dense(512, activation='relu', input_dim=1))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
latent_dim = 100
generator = build_generator(latent_dim)
discriminator = build_discriminator()
discriminator.compile(optimizer='adam', loss='binary_crossentropy')
discriminator.trainable = False

# %%
discriminator.compile(optimizer='adam', loss='binary_crossentropy')
discriminator.trainable = False

# %%
gan_input = layers.Input(shape=(latent_dim,))
generated_note = generator(gan_input)
gan_output = discriminator(generated_note)
gan = tf.keras.Model(gan_input, gan_output)

gan.compile(optimizer='adam', loss='binary_crossentropy')

# %%
def train_gan(gan, generator, discriminator, data, epochs, batch_size, latent_dim):
    for epoch in range(epochs):
        idx = np.random.randint(0, data.shape[0], batch_size)
        real_notes = data[idx]
        
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        generated_notes = generator.predict(noise)
        
        combined_data = np.concatenate([real_notes, generated_notes])
        labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
        
        d_loss = discriminator.train_on_batch(combined_data, labels)
        
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        misleading_labels = np.ones((batch_size, 1))
        g_loss = gan.train_on_batch(noise, misleading_labels)
        
        if epoch % 100 == 0:
            print(f"Epoch {epoch}, Discriminator Loss: {d_loss}, Generator Loss: {g_loss}")

train_gan(gan, generator, discriminator, normalized_notes, epochs=1000, batch_size=64, latent_dim=latent_dim)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 0, Discriminator Loss: 0.6909331679344177, Generator Loss: [array(0.69093317, dtype=float32), array(0.69093317, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 100, Discriminator Loss: 0.7008066177368164, Generator Loss: [array(0.7008066, dtype=float32), array(0.7008066, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Epoch 200, Discriminator Loss: 0.7009196877479553, Generator Loss: [array(0.7009197, dtype=float32), array(0.7009197, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Epoch 300, Discriminator Loss: 0.70097815990448, Generator Loss: [array(0.70097816, dtype=float32), array(0.70097816, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Epoch 400, Discriminator Loss: 0.7009903192520142, Generator Loss: [array(0.7009903, dtype=float32), array(0.7009903, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Epoch 500, Discriminator Loss: 0.7010005116462708, Generator Loss: [array(0.7010005, dtype=float32), array(0.7010005, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step
# Epoch 600, Discriminator Loss: 0.701005756855011, Generator Loss: [array(0.70100576, dtype=float32), array(0.70100576, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 700, Discriminator Loss: 0.7010110020637512, Generator Loss: [array(0.701011, dtype=float32), array(0.701011, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 800, Discriminator Loss: 0.7010132074356079, Generator Loss: [array(0.7010132, dtype=float32), array(0.7010132, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 900, Discriminator Loss: 0.701013445854187, Generator Loss: [array(0.70101345, dtype=float32), array(0.70101345, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %%
def generate_music(generator, latent_dim):
    noise = np.random.normal(0, 1, (1, latent_dim))
    generated_notes = generator.predict(noise)
    return generated_notes

# %%
def denormalize_notes(notes, min_note, max_note):
    return [int(note * (max_note - min_note) + min_note) for note in notes]

# %%
generated_notes = generate_music(generator, latent_dim)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %%
denormalized_notes = denormalize_notes(generated_notes, min_note, max_note)
# Out:
# C:\Users\Student_B21\AppData\Local\Temp\ipykernel_4284\3250715730.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return [int(note * (max_note - min_note) + min_note) for note in notes]

# %%
def notes_to_midi(notes, output_file):
    midi = MidiFile()
    track = MidiTrack()
    midi.tracks.append(track)
    
    for note in notes:
        track.append(Message('note_on', note=note, velocity=64, time=480))
        track.append(Message('note_off', note=note, velocity=64, time=960))
    
    midi.save(output_file)

output_file = 'generated_music.mid'
notes_to_midi(denormalized_notes, output_file)
